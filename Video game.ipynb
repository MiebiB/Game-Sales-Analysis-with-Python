# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
#      -------------------------------------- 15.9/15.9 MB 676.2 kB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.0.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2.0.2)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      -------------------------------------- 347.8/347.8 KB 1.5 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      -------------------------------------- 509.2/509.2 KB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
print("Testing")
# Out:
# Testing

# %%
import pandas as pd
import numpy as np

ts=pd.read_csv('C:/Users/USER/Downloads/VideoGamesProject-main/VideoGamesProject-main/VideoGamesSales.csv') #imports the data
df=ts[ts.duplicated()] #shows all duplicate rows
df
# Out:
#       Rank                                               Name Platform  Year  \
# 9        9                          New Super Mario Bros. Wii      Wii  2010
# 10       9                          New Super Mario Bros. Wii      Wii  2010
# 11       9                          New Super Mario Bros. Wii      Wii  2010
# 12       9                          New Super Mario Bros. Wii      Wii  2010
# 64      60                                     Super Mario 64       DS  2010
# 65      60                                     Super Mario 64       DS  2010
# 66      60                                     Super Mario 64       DS  2010
# 380    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 381    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 382    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 1658  1649                                         WCW Mayhem       PS  2015
# 1659  1649                                         WCW Mayhem       PS  2015
# 1660  1649                                         WCW Mayhem       PS  2015
# 5888  5876                                 Dynasty Warriors 6     X360  2017
# 5889  5876                                 Dynasty Warriors 6     X360  2017
# 5890  5876                                 Dynasty Warriors 6     X360  2017
#
#      Month     Genre        Publisher        Country       City  \
# 9      Sep  Platform         Nintendo            USA  Fairfield
# 10     Sep  Platform         Nintendo            USA  Fairfield
# 11     Sep  Platform         Nintendo            USA  Fairfield
# 12     Sep  Platform         Nintendo            USA  Fairfield
# 64     Dec  Platform         Nintendo  United States    Seattle
# 65     Dec  Platform         Nintendo  United States    Seattle
# 66     Dec  Platform         Nintendo  United States    Seattle
# 380    Jan  Platform         Nintendo  United States  Lancaster
# 381    Jan  Platform         Nintendo  United States  Lancaster
# 382    Jan  Platform         Nintendo  United States  Lancaster
# 1658   Apr  Fighting  Electronic Arts  United States      Akron
# 1659   Apr  Fighting  Electronic Arts  United States      Akron
# 1660   Apr  Fighting  Electronic Arts  United States      Akron
# 5888   Jul    Action       Tecmo Koei      Australia     Sydney
# 5889   Jul    Action       Tecmo Koei      Australia     Sydney
# 5890   Jul    Action       Tecmo Koei      Australia     Sydney
#
#                 State Region NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 9                Ohio   East   $14.59         28.62      4.377          8.586
# 10               Ohio   East   $14.59         28.62      4.377          8.586
# 11               Ohio   East   $14.59         28.62      4.377          8.586
# 12               Ohio   East   $14.59         28.62      4.377          8.586
# 64         Washington   West     5.08         10.42      1.524          3.126
# 65         Washington   West     5.08         10.42      1.524          3.126
# 66         Washington   West     5.08         10.42      1.524          3.126
# 380              Ohio   East     1.17          3.51      0.351          1.053
# 381              Ohio   East     1.17          3.51      0.351          1.053
# 382              Ohio   East     1.17          3.51      0.351          1.053
# 1658             Ohio   East     0.68          1.22      0.204          0.366
# 1659             Ohio   East     0.68          1.22      0.204          0.366
# 1660             Ohio   East     0.68          1.22      0.204          0.366
# 5888  New South Wales   West     0.15          0.30      0.045          0.090
# 5889  New South Wales   West     0.15          0.30      0.045          0.090
# 5890  New South Wales   West     0.15          0.30      0.045          0.090

# %%
df.shape[0] #shows number of rows of the current df
# Out:
# 16

# %%
ts.shape[1] #shows number of columns of the original data (ts)
# Out:
# 15

# %%
ts.shape[0] #shows number of rows of the original data (ts)
# Out:
# 5909

# %%
ts=ts.drop_duplicates() #deletes all the duplicate rows
ts.shape[0] #new count (5909-16=5893)
# Out:
# 5893

# %%
ts.info() #without () gives more details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5909 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5909 non-null   int64
#  1   Name           5909 non-null   object
#  2   Platform       5909 non-null   object
#  3   Year           5909 non-null   int64
#  4   Month          5909 non-null   object
#  5   Genre          5909 non-null   object
#  6   Publisher      5897 non-null   object
#  7   Country        5909 non-null   object
#  8   City           5909 non-null   object
#  9   State          5909 non-null   object
#  10  Region         5882 non-null   object
#  11  NA_Sales       5909 non-null   object
#  12  Global_Sales   5909 non-null   float64
#  13  NA_Profit      5909 non-null   float64
#  14  Global_Profit  5909 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 692.6+ KB

# %%
ts['Region']=ts['Region'].fillna('North') #replace empty cells in Rehion column with 'North'
rg=rg[ts['Region'].isnull()]
rg.shape[0] #new empty column counts bring in 0
# Out:
# 0

# %%
import pandas as pd
import numpy as np

ts=pd.read_csv('C:/Users/USER/Downloads/VideoGamesProject-main/VideoGamesProject-main/VideoGamesSales.csv') #imports the data
df=ts[ts.duplicated()] #shows all duplicate rows
df
# Out:
#       Rank                                               Name Platform  Year  \
# 9        9                          New Super Mario Bros. Wii      Wii  2010
# 10       9                          New Super Mario Bros. Wii      Wii  2010
# 11       9                          New Super Mario Bros. Wii      Wii  2010
# 12       9                          New Super Mario Bros. Wii      Wii  2010
# 64      60                                     Super Mario 64       DS  2010
# 65      60                                     Super Mario 64       DS  2010
# 66      60                                     Super Mario 64       DS  2010
# 380    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 381    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 382    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 1658  1649                                         WCW Mayhem       PS  2015
# 1659  1649                                         WCW Mayhem       PS  2015
# 1660  1649                                         WCW Mayhem       PS  2015
# 5888  5876                                 Dynasty Warriors 6     X360  2017
# 5889  5876                                 Dynasty Warriors 6     X360  2017
# 5890  5876                                 Dynasty Warriors 6     X360  2017
#
#      Month     Genre        Publisher        Country       City  \
# 9      Sep  Platform         Nintendo            USA  Fairfield
# 10     Sep  Platform         Nintendo            USA  Fairfield
# 11     Sep  Platform         Nintendo            USA  Fairfield
# 12     Sep  Platform         Nintendo            USA  Fairfield
# 64     Dec  Platform         Nintendo  United States    Seattle
# 65     Dec  Platform         Nintendo  United States    Seattle
# 66     Dec  Platform         Nintendo  United States    Seattle
# 380    Jan  Platform         Nintendo  United States  Lancaster
# 381    Jan  Platform         Nintendo  United States  Lancaster
# 382    Jan  Platform         Nintendo  United States  Lancaster
# 1658   Apr  Fighting  Electronic Arts  United States      Akron
# 1659   Apr  Fighting  Electronic Arts  United States      Akron
# 1660   Apr  Fighting  Electronic Arts  United States      Akron
# 5888   Jul    Action       Tecmo Koei      Australia     Sydney
# 5889   Jul    Action       Tecmo Koei      Australia     Sydney
# 5890   Jul    Action       Tecmo Koei      Australia     Sydney
#
#                 State Region NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 9                Ohio   East   $14.59         28.62      4.377          8.586
# 10               Ohio   East   $14.59         28.62      4.377          8.586
# 11               Ohio   East   $14.59         28.62      4.377          8.586
# 12               Ohio   East   $14.59         28.62      4.377          8.586
# 64         Washington   West     5.08         10.42      1.524          3.126
# 65         Washington   West     5.08         10.42      1.524          3.126
# 66         Washington   West     5.08         10.42      1.524          3.126
# 380              Ohio   East     1.17          3.51      0.351          1.053
# 381              Ohio   East     1.17          3.51      0.351          1.053
# 382              Ohio   East     1.17          3.51      0.351          1.053
# 1658             Ohio   East     0.68          1.22      0.204          0.366
# 1659             Ohio   East     0.68          1.22      0.204          0.366
# 1660             Ohio   East     0.68          1.22      0.204          0.366
# 5888  New South Wales   West     0.15          0.30      0.045          0.090
# 5889  New South Wales   West     0.15          0.30      0.045          0.090
# 5890  New South Wales   West     0.15          0.30      0.045          0.090

# %%
ts.shape[0]
# Out:
# 5909

# %%
ts.shape[1]
# Out:
# 15

# %%
ts=ts.drop_duplicates() #deletes all the duplicate rows
ts.shape[0] #new count (5909-16=5893)
# Out:
# 5893

# %%
ts_backup = ts.copy() #creating backup

# %%
ts['Region'].unique() #check what values are there
# Out:
# array(['West', 'South', 'Central', 'East', nan, 'Other', 'North'],
#       dtype=object)

# %%
ts['Region'] = ts['Region'].replace(r'^\s*$', np.nan, regex=True) #replaces empty strings or strings with only spaces with np.nan
ts['Region'] = ts['Region'].fillna('North') # Now use fillna to replace actual missing values
ts['Region'].isnull().sum() #to verify that there are no missing values
# Out:
# np.int64(0)

# %%
ts.head(10) #shows the last 10 rows in the table
# Out:
#     Rank                       Name Platform  Year Month         Genre  \
# 0      1                 Wii Sports      Wii  2010   Jan        Sports
# 1      2          Super Mario Bros.      NES  2010   Feb      Platform
# 2      3             Mario Kart Wii      Wii  2010   Mar        Racing
# 3      4          Wii Sports Resort      Wii  2010   Apr        Sports
# 4      5   Pokemon Red/Pokemon Blue       GB  2010   May  Role-Playing
# 5      6                     Tetris       GB  2010   Jun        Puzzle
# 6      7      New Super Mario Bros.       DS  2010   Jul      Platform
# 7      8                   Wii Play      Wii  2010   Aug          Misc
# 8      9  New Super Mario Bros. Wii      Wii  2010   Sep      Platform
# 13    10                  Duck Hunt      NES  2010   Oct       Shooter
#
#    Publisher        Country        City       State   Region NA_Sales  \
# 0   Nintendo  United States   Fairfield  California     West   $41.49
# 1   Nintendo  United States     Edmonds  Washington     West   $29.08
# 2   Nintendo  United States  Louisville    Kentucky    South   $15.85
# 3   Nintendo  United States  Round Rock       Texas  Central   $15.75
# 4   Nintendo  United States   Nashville   Tennessee    South   $11.27
# 5   Nintendo            USA      Newark        Ohio     East   $23.20
# 6   Nintendo            USA     Fremont    Nebraska  Central   $11.38
# 7   Nintendo            USA      Odessa       Texas  Central   $14.03
# 8   Nintendo            USA   Fairfield        Ohio     East   $14.59
# 13  Nintendo            USA      Dallas       Texas    North   $26.93
#
#     Global_Sales  NA_Profit  Global_Profit
# 0          82.74     12.447         24.822
# 1          40.24      8.724         12.072
# 2          35.82      4.755         10.746
# 3          33.00      4.725          9.900
# 4          31.37      3.381          9.411
# 5          30.26      6.960          9.078
# 6          30.01      3.414          9.003
# 7          29.02      4.209          8.706
# 8          28.62      4.377          8.586
# 13         28.31      8.079          8.493

# %%
ts['NA_Sales']=ts['NA_Sales'].replace(r'[$]', '', regex=True) #replace $ with nothing
ts['NA_Sales']=pd.to_numeric(ts['NA_Sales'], errors='coerce') #change to float numeric
Average_sales=ts['NA_Sales'].mean()
Average_sales=int(Average_sales)
Average_sales #gives 0 as average
ts['NA_Sales']=ts['NA_Sales'].fillna(Average_sales)
ts
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# 0           Sports            Nintendo  United States   Fairfield
# 1         Platform            Nintendo  United States     Edmonds
# 2           Racing            Nintendo  United States  Louisville
# 3           Sports            Nintendo  United States  Round Rock
# 4     Role-Playing            Nintendo  United States   Nashville
# ...            ...                 ...            ...         ...
# 5904        Racing                 THQ      Australia      Sydney
# 5905    Simulation     Electronic Arts      Australia      Sydney
# 5906        Action     Electronic Arts      Australia      Sydney
# 5907        Action          Activision      Australia      Sydney
# 5908    Simulation  Namco Bandai Games      Australia      Sydney
#
#                 State   Region  NA_Sales  Global_Sales  NA_Profit  \
# 0          California     West     41.49         82.74     12.447
# 1          Washington     West     29.08         40.24      8.724
# 2            Kentucky    South     15.85         35.82      4.755
# 3               Texas  Central     15.75         33.00      4.725
# 4           Tennessee    South     11.27         31.37      3.381
# ...               ...      ...       ...           ...        ...
# 5904  New South Wales     West      0.21          0.30      0.063
# 5905  New South Wales     West      0.15          0.30      0.045
# 5906  New South Wales     West      0.24          0.30      0.072
# 5907  New South Wales     West      0.17          0.30      0.051
# 5908  New South Wales     West      0.00          0.30      0.000
#
#       Global_Profit
# 0            24.822
# 1            12.072
# 2            10.746
# 3             9.900
# 4             9.411
# ...             ...
# 5904          0.090
# 5905          0.090
# 5906          0.090
# 5907          0.090
# 5908          0.090
#
# [5893 rows x 15 columns]

# %%
ts['Country']=ts['Country'].replace({'USA':'United States'}) #replace USA with United States
ts.head(10)
# Out:
#     Rank                       Name Platform  Year Month         Genre  \
# 0      1                 Wii Sports      Wii  2010   Jan        Sports
# 1      2          Super Mario Bros.      NES  2010   Feb      Platform
# 2      3             Mario Kart Wii      Wii  2010   Mar        Racing
# 3      4          Wii Sports Resort      Wii  2010   Apr        Sports
# 4      5   Pokemon Red/Pokemon Blue       GB  2010   May  Role-Playing
# 5      6                     Tetris       GB  2010   Jun        Puzzle
# 6      7      New Super Mario Bros.       DS  2010   Jul      Platform
# 7      8                   Wii Play      Wii  2010   Aug          Misc
# 8      9  New Super Mario Bros. Wii      Wii  2010   Sep      Platform
# 13    10                  Duck Hunt      NES  2010   Oct       Shooter
#
#    Publisher        Country        City       State   Region  NA_Sales  \
# 0   Nintendo  United States   Fairfield  California     West     41.49
# 1   Nintendo  United States     Edmonds  Washington     West     29.08
# 2   Nintendo  United States  Louisville    Kentucky    South     15.85
# 3   Nintendo  United States  Round Rock       Texas  Central     15.75
# 4   Nintendo  United States   Nashville   Tennessee    South     11.27
# 5   Nintendo  United States      Newark        Ohio     East     23.20
# 6   Nintendo  United States     Fremont    Nebraska  Central     11.38
# 7   Nintendo  United States      Odessa       Texas  Central     14.03
# 8   Nintendo  United States   Fairfield        Ohio     East     14.59
# 13  Nintendo  United States      Dallas       Texas    North     26.93
#
#     Global_Sales  NA_Profit  Global_Profit
# 0          82.74     12.447         24.822
# 1          40.24      8.724         12.072
# 2          35.82      4.755         10.746
# 3          33.00      4.725          9.900
# 4          31.37      3.381          9.411
# 5          30.26      6.960          9.078
# 6          30.01      3.414          9.003
# 7          29.02      4.209          8.706
# 8          28.62      4.377          8.586
# 13         28.31      8.079          8.493

# %%
ts['Country']=ts['Country'].str.title() #puts the first letters in uppercase
#ts['Country']=ts[ts['Country']=='United States'] #gives only values with United States

# %%
#to rename column names
ts=ts.rename(columns={'NA_Sales':'National Sales', 'Global_Sales':'Global Sales', 'NA_Profit':'National Profit', 'Global_Profit':'Global Profit'})
ts
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# 0           Sports            Nintendo  United States   Fairfield
# 1         Platform            Nintendo  United States     Edmonds
# 2           Racing            Nintendo  United States  Louisville
# 3           Sports            Nintendo  United States  Round Rock
# 4     Role-Playing            Nintendo  United States   Nashville
# ...            ...                 ...            ...         ...
# 5904        Racing                 THQ      Australia      Sydney
# 5905    Simulation     Electronic Arts      Australia      Sydney
# 5906        Action     Electronic Arts      Australia      Sydney
# 5907        Action          Activision      Australia      Sydney
# 5908    Simulation  Namco Bandai Games      Australia      Sydney
#
#                 State   Region  National Sales  Global Sales  National Profit  \
# 0          California     West           41.49         82.74           12.447
# 1          Washington     West           29.08         40.24            8.724
# 2            Kentucky    South           15.85         35.82            4.755
# 3               Texas  Central           15.75         33.00            4.725
# 4           Tennessee    South           11.27         31.37            3.381
# ...               ...      ...             ...           ...              ...
# 5904  New South Wales     West            0.21          0.30            0.063
# 5905  New South Wales     West            0.15          0.30            0.045
# 5906  New South Wales     West            0.24          0.30            0.072
# 5907  New South Wales     West            0.17          0.30            0.051
# 5908  New South Wales     West            0.00          0.30            0.000
#
#       Global Profit
# 0            24.822
# 1            12.072
# 2            10.746
# 3             9.900
# 4             9.411
# ...             ...
# 5904          0.090
# 5905          0.090
# 5906          0.090
# 5907          0.090
# 5908          0.090
#
# [5893 rows x 15 columns]

# %%
#!pip install matplotlib
#!pip install seaborn

#sales_cap=ts['National Sales'].quantile(0.95) #means that 95% of values are less than what is shown what i execute sales_cap

#ts['National Sales']=np.where(ts['National Sales'] > sales_cap, sales_cap, ts['National Sales'])
#ts

gsales_cap=ts['Global Sales'].quantile(0.95) #means that 95% of values are less than what is shown what i execute sales_cap
#gsales_cap

ts['Global Sales']=np.where(ts['Global Sales'] > gsales_cap, gsales_cap, ts['Global Sales'])
ts
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# 0           Sports            Nintendo  United States   Fairfield
# 1         Platform            Nintendo  United States     Edmonds
# 2           Racing            Nintendo  United States  Louisville
# 3           Sports            Nintendo  United States  Round Rock
# 4     Role-Playing            Nintendo  United States   Nashville
# ...            ...                 ...            ...         ...
# 5904        Racing                 THQ      Australia      Sydney
# 5905    Simulation     Electronic Arts      Australia      Sydney
# 5906        Action     Electronic Arts      Australia      Sydney
# 5907        Action          Activision      Australia      Sydney
# 5908    Simulation  Namco Bandai Games      Australia      Sydney
#
#                 State   Region  National Sales  Global Sales  National Profit  \
# 0          California     West            2.07         4.038           12.447
# 1          Washington     West            2.07         4.038            8.724
# 2            Kentucky    South            2.07         4.038            4.755
# 3               Texas  Central            2.07         4.038            4.725
# 4           Tennessee    South            2.07         4.038            3.381
# ...               ...      ...             ...           ...              ...
# 5904  New South Wales     West            0.21         0.300            0.063
# 5905  New South Wales     West            0.15         0.300            0.045
# 5906  New South Wales     West            0.24         0.300            0.072
# 5907  New South Wales     West            0.17         0.300            0.051
# 5908  New South Wales     West            0.00         0.300            0.000
#
#       Global Profit
# 0            24.822
# 1            12.072
# 2            10.746
# 3             9.900
# 4             9.411
# ...             ...
# 5904          0.090
# 5905          0.090
# 5906          0.090
# 5907          0.090
# 5908          0.090
#
# [5893 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns



 #to create bar chart
National_Sales=ts.groupby(['Region','Country'])['National Sales'].sum().reset_index().sort_values(by='National Sales', ascending=False)
National_Sales
plt.figure(figsize=(16,8))
sns.barplot(data=National_Sales, x='Region', y='National Sales', hue='Country')
plt.title('National Sales by region and country')
plt.xlabel('region')
plt.ylabel('National Sales')
plt.show()

# %%
#create box plot

plt.figure(figure=(10,6))
sns.boxplot(x='Country', y='National Sales', data=ts, hue='Genre')
plt.title('National Sales by Country')
plt.xlabel('Country', fontweight='bold')
plt.ylabel('National Sales', fontweight='bold')
plt.show()

# %%
#Create pie chart

Sales = ts.groupby(['Country'])[['National Sales', 'Global Sales']].sum().reset_index()
Country=Sales['Country']
National_Sales=Sales['National Sales']
Global_Sales=Sales['Global Sales']

fig, axs=plt.subplots(1,2,figsize=(10,7))

axs[0].pie(National_Sales, labels=Country, autopct='%1.1f%%',startangle=30)
axs[0].set_title('National Sales by Country')

axs[1].pie(Global_Sales, labels=Country, autopct='%1.1f%%',startangle=30)
axs[1].set_title('Global Sales by Country')

plt.show()

# %%
#create line chart

sales_by_year = ts.groupby('Year')[['National Sales', 'Global Sales']].sum().reset_index()

plt.figure(figsize=(10,6))

plt.plot(sales_by_year['Year'], sales_by_year['National Sales'], marker='o', linestyle='-', color='b', label='National Sales') #line plot for National Sales

plt.plot(sales_by_year['Year'], sales_by_year['Global Sales'], marker='s', linestyle='--', color='g', label='Global Sales') #line plot for Global Sales

plt.title('National and Global Sales Over Years')
plt.xlabel('Year', fontweight='bold')
plt.ylabel('Sales', fontweight='bold')
plt.legend()

plt.grid(True) #add grid
plt.show()

# %%
ts
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# 0           Sports            Nintendo  United States   Fairfield
# 1         Platform            Nintendo  United States     Edmonds
# 2           Racing            Nintendo  United States  Louisville
# 3           Sports            Nintendo  United States  Round Rock
# 4     Role-Playing            Nintendo  United States   Nashville
# ...            ...                 ...            ...         ...
# 5904        Racing                 THQ      Australia      Sydney
# 5905    Simulation     Electronic Arts      Australia      Sydney
# 5906        Action     Electronic Arts      Australia      Sydney
# 5907        Action          Activision      Australia      Sydney
# 5908    Simulation  Namco Bandai Games      Australia      Sydney
#
#                 State   Region  National Sales  Global Sales  National Profit  \
# 0          California     West            2.07         4.038           12.447
# 1          Washington     West            2.07         4.038            8.724
# 2            Kentucky    South            2.07         4.038            4.755
# 3               Texas  Central            2.07         4.038            4.725
# 4           Tennessee    South            2.07         4.038            3.381
# ...               ...      ...             ...           ...              ...
# 5904  New South Wales     West            0.21         0.300            0.063
# 5905  New South Wales     West            0.15         0.300            0.045
# 5906  New South Wales     West            0.24         0.300            0.072
# 5907  New South Wales     West            0.17         0.300            0.051
# 5908  New South Wales     West            0.00         0.300            0.000
#
#       Global Profit
# 0            24.822
# 1            12.072
# 2            10.746
# 3             9.900
# 4             9.411
# ...             ...
# 5904          0.090
# 5905          0.090
# 5906          0.090
# 5907          0.090
# 5908          0.090
#
# [5893 rows x 15 columns]
